# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Loading the data set

# %%
df = pd.read_csv("/Users/karanbhutani/Downloads/creditcard.csv")

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
df.head(4)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %% [markdown]
# the time column tells us that the data is of about 48 hours

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# the number of columns and data type of the columns

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# there are no null values in a data set

# %%
df.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
#
# ...

# %%
df["Class"].unique()
# Out:
# array([0, 1])

# %%
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# We have about 492 fraudulent transactions
# Normal trans - 0
# fraud trans  - 1

# %% [markdown]
# This data is imbalanced due to the following reasons
# 1 - About 99 percent of the transactions belong to 1 class and if we train on this data and feed it to a model then it is anyways going to overfit.

# %% [markdown]
# Seperating data for analysis

# %%
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit.head(4)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# ...

# %%
fraud.head(3)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9       V10       V11       V12       V13  \
# 541  -2.537387  1.391657 -2.770089 -2.772272  3.202033 -2.899907 -0.595222
# 623   0.325574 -0.067794 -0.270953 -0.838587 -0.414575 -0.503141  0.676502
# 4920  0.562320 -0.399147 -0.238253 -1.525412  2.032912 -6.560124  0.022937
#
#            V14       V15       V16       V17       V18       V19       V20  \
# 541  -4.289254  0.389724 -1.140747 -2.830056 -0.016822  0.416956  0.126911
# 623  -1.692029  2.000635  0.666780  0.599717  1.725321  0.283345  2.102339
# 4920 -1.470102 -0.698826 -2.282194 -4.781831 -2.615665 -1.334441 -0.430022
#
# ...

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0      0.002419  0.009637 -0.000987  0.004467  0.009824 -0.006576  0.010832
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0      0.000189  0.012064  0.000161  0.007164  0.011535  0.003887 -0.001178
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0     -0.000644 -0.001235 -0.000024  0.000070  0.000182 -0.000072 -0.000089
# 1      0.372319  0.713588  0.014049 -0.040308 -0.105130  0.041449  0.051648
#
# ...

# %% [markdown]
# ## Undersampling
# Building a sample data set comtaining a similar distribution of normal transaction fraud transaction

# %%
legit_sample = legit.sample(n=492)

# %%
legit_sample.shape
# Out:
# (492, 31)

# %%
new_df = pd.concat([legit_sample, fraud],axis=0)

# %%
new_df.shape
# Out:
# (984, 31)

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 57668    48007.0  0.937506 -0.162797  0.396120  1.034434 -0.355306 -0.088302
# 15187    26538.0 -0.772598  0.013121  2.854190 -0.764668 -1.671336 -0.394660
# 216135  140355.0 -0.303772  0.500207  1.547206 -0.579101 -0.026360 -0.236697
# 215214  139978.0  1.401099 -0.981455 -1.704916  0.155916 -0.334771 -0.474435
# 183477  125819.0  1.802582  0.114156 -0.428993  3.950086  0.235051  0.762772
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 57668  -0.006215  0.149276 -0.059352  0.088332  1.409085  0.448391 -1.172437
# 15187  -0.662285  0.068943 -0.819274  0.478284 -0.473720 -0.839830 -0.234586
# 216135  0.290225  0.055599  0.245113 -0.807403 -0.792806  0.422016  0.700211
# 215214 -0.111081 -0.001124  0.676238 -1.018707  1.750119  0.748550  0.219948
# 183477 -0.210014  0.156545 -0.189785  1.267450 -1.862135 -0.299808 -0.539248
#
# ...

# %%
new_df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 279863 -0.882850  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123
# 280143 -1.413170  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532
# 280149 -2.234739  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950
# 281144 -2.208002  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455
# 281674  0.223050 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428
#
# ...

# %%
new_df['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92823.532520 -0.152960  0.138417 -0.002092 -0.042110 -0.056518
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0     -0.037093 -0.010389 -0.089900  0.001703  0.023766  0.046086  0.005382
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0     -0.051403 -0.023305  0.029205 -0.024838  0.063485  0.073773 -0.024328
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0      0.027793 -0.060780  0.028194 -0.006578  0.055932  0.014683 -0.033098
# 1      0.372319  0.713588  0.014049 -0.040308 -0.105130  0.041449  0.051648
#
# ...

# %% [markdown]
# Splitting the data into features and targets

# %%
x = new_df.drop(columns='Class',axis=1)
y = new_df['Class']

# %%
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 57668    48007.0  0.937506 -0.162797  0.396120  1.034434 -0.355306 -0.088302
# 15187    26538.0 -0.772598  0.013121  2.854190 -0.764668 -1.671336 -0.394660
# 216135  140355.0 -0.303772  0.500207  1.547206 -0.579101 -0.026360 -0.236697
# 215214  139978.0  1.401099 -0.981455 -1.704916  0.155916 -0.334771 -0.474435
# 183477  125819.0  1.802582  0.114156 -0.428993  3.950086  0.235051  0.762772
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 57668     0
# 15187     0
# 216135    0
# 215214    0
# 183477    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2, stratify = y)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (787, 30) (197, 30)

# %% [markdown]
# Model Training

# %%
model = LogisticRegression()

# %% [markdown]
# Trainig the Logistic Model with training Data

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
x_train_pred = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_pred, y_train)
print('Accuracy on training data' , training_data_accuracy*100)
# Out:
# Accuracy on training data 94.53621346886912

# %% [markdown]
# Accuracy on test data

# %%
x_test_pred = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_pred, y_test)
print('Accuracy on Test Data:', test_data_accuracy*100)
# Out:
# Accuracy on Test Data: 90.35532994923858
