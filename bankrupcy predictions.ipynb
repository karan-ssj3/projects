# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/Users/karanbhutani/Downloads/data.csv')

# %%
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
data.corr()
# Out:
#                                                     Bankrupt?  \
# Bankrupt?                                            1.000000
#  ROA(C) before interest and depreciation before...  -0.260807
#  ROA(A) before interest and % after tax             -0.282941
#  ROA(B) before interest and depreciation after tax  -0.273051
#  Operating Gross Margin                             -0.100043
# ...                                                       ...
#  Liability to Equity                                 0.166812
#  Degree of Financial Leverage (DFL)                  0.010508
#  Interest Coverage Ratio (Interest expense to E...  -0.005509
#  Net Income Flag                                          NaN
#  Equity to Liability                                -0.083048
#
#                                                      ROA(C) before interest and depreciation before interest  \
# Bankrupt?                                                                                   -0.260807
# ...

# %%
sns.heatmap(data.corr(), annot=False, annot_kws={'size': 50})
# Out:
# <AxesSubplot:>

# %%
data.skew()
# Out:
# Bankrupt?                                                    5.295388
#  ROA(C) before interest and depreciation before interest    -0.323941
#  ROA(A) before interest and % after tax                     -1.033727
#  ROA(B) before interest and depreciation after tax          -0.763564
#  Operating Gross Margin                                     -8.043368
#                                                               ...
#  Liability to Equity                                        27.459467
#  Degree of Financial Leverage (DFL)                         45.724197
#  Interest Coverage Ratio (Interest expense to EBIT)        -13.939528
#  Net Income Flag                                             0.000000
#  Equity to Liability                                         7.401101
# Length: 96, dtype: float64

# %%
sns.violinplot(data.skew())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
from scipy.stats import skew

# %%
for col in data:
    print(col)
    print(skew(data[col]))
    
    plt.figure()
    sns.violinplot(data[col])
    plt.show()
# Out:
# Bankrupt?
# 5.294222599216838
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#  ROA(C) before interest and depreciation before interest
# -0.323869740413385
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#  ROA(A) before interest and % after tax
# -1.0334994309305
# ...

# %%
x= data.drop("Bankrupt?",axis=1)
y= data["Bankrupt?"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
classifier=LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 96.93469569080409

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators = 100)

# %%
clf.fit(X_test,y_test)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)*100
# Out:
# 100.0

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_classification
X, y= make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=0, random_state=0, shuffle=False)

# %%
clf=AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
clf.fit(X, y)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
clf.predict([[0, 0, 0, 0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 clf.predict([[0, 0, 0, 0]])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:699, in AdaBoostClassifier.predict(self, X)
#     682 def predict(self, X):
#     683     """Predict classes for X.
#     684
#     685     The predicted class of an input sample is computed as the weighted mean
#    (...)
#     697         The predicted classes.
#     698     """
# --> 699     pred = self.decision_function(X)
#     701     if self.n_classes_ == 2:
#     702         return self.classes_.take(pred > 0, axis=0)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:760, in AdaBoostClassifier.decision_function(self, X)
# ...

# %%
 clf.score(X, y)*100
# Out:
# 98.3
